# %%
from mods import YanAPI
import pprint

ip_addr_1= "192.168.3.51" 
YanAPI.yan_api_init(ip_addr_1)
pprint.pp(YanAPI.get_motion_list_value())
# Out:
# ['EnterEnergySavingSquat',
#  '青春修炼手册',
#  'SweetAndSour',
#  'TurnRight',
#  'LeftSidePunch',
#  'Move_fast',
#  'ResetSwitch',
#  'TurnRightSlowly',
#  'Football_RSideK',
#  '我和我的祖国',
#  'TurnR_tiny',
#  'Shutdown',
#  'TurnLeftSlowly',
#  'Fight_RHit',
#  '没有共产党就没新中国',
#  'WeAreTakingOff',
#  'RightTackle',
#  'Football_RKeep',
#  'Football_LSideK',
#  'GoalKeeper2',
#  'OneStepForward',
#  'OneStepTurnRight',
#  'calibration_new',
#  '创客星球',
#  'SiegeOfTroy',
#  'RaiseRightHand',
#  'ShootRight',
#  'Base_GetupF',
#  'WakaWaka',
#  '圣诞快乐',
#  'LeftTackle',
#  'TurnRight1',
#  'Football_RKick',
#  'Backward',
#  '我们是共产主义接班人',
#  'SorrySorry',
#  'Base_GetupB',
#  'reset_without_head',
#  'Base_Forward',
#  'GetupFront',
#  'TurnL_tiny',
#  'Rightward',
#  'Victory',
#  'Base_Leftward',
#  'rightmovestep',
#  'Football_RShoot',
#  'RightHitForward',
#  'Leftward',
#  'TurnLeft',
#  'HappyBirthday',
#  'TurnLeft1',
#  'Base_Rightward',
#  'Fight_LSideHit',
#  '从这里出发',
# ...

# %%
YanAPI.sync_play_motion(name='GoalKeeper1')
YanAPI.stop_play_motion()
# Out:
# {'code': 0, 'data': {'total_time': 0}, 'msg': 'success'}
