# %%
from mods import YanAPI
import pprint

ip_addr_1= "192.168.3.51" 
YanAPI.yan_api_init(ip_addr_1)
pprint.pp(YanAPI.get_motion_list())
# Out:
# {'code': 0,
#  'data': {'system_hts_motions': [{'music': False,
#                                   'name': 'EnterEnergySavingSquat'},
#                                  {'music': True, 'name': '青春修炼手册'},
#                                  {'music': True, 'name': 'SweetAndSour'},
#                                  {'music': False, 'name': 'TurnRight'},
#                                  {'music': False, 'name': 'LeftSidePunch'},
#                                  {'music': False, 'name': 'Move_fast'},
#                                  {'music': False, 'name': 'ResetSwitch'},
#                                  {'music': False, 'name': 'TurnRightSlowly'},
#                                  {'music': False, 'name': 'Football_RSideK'},
#                                  {'music': True, 'name': '我和我的祖国'},
#                                  {'music': False, 'name': 'TurnR_tiny'},
#                                  {'music': False, 'name': 'Shutdown'},
#                                  {'music': False, 'name': 'TurnLeftSlowly'},
#                                  {'music': False, 'name': 'Fight_RHit'},
#                                  {'music': True, 'name': '没有共产党就没新中国'},
#                                  {'music': True, 'name': 'WeAreTakingOff'},
#                                  {'music': False, 'name': 'RightTackle'},
#                                  {'music': False, 'name': 'Football_RKeep'},
#                                  {'music': False, 'name': 'Football_LSideK'},
#                                  {'music': False, 'name': 'GoalKeeper2'},
#                                  {'music': False, 'name': 'OneStepForward'},
#                                  {'music': False, 'name': 'OneStepTurnRight'},
#                                  {'music': False, 'name': 'calibration_new'},
#                                  {'music': True, 'name': '创客星球'},
#                                  {'music': True, 'name': 'SiegeOfTroy'},
#                                  {'music': False, 'name': 'RaiseRightHand'},
#                                  {'music': False, 'name': 'ShootRight'},
#                                  {'music': False, 'name': 'Base_GetupF'},
#                                  {'music': True, 'name': 'WakaWaka'},
#                                  {'music': True, 'name': '圣诞快乐'},
#                                  {'music': False, 'name': 'LeftTackle'},
#                                  {'music': False, 'name': 'TurnRight1'},
#                                  {'music': False, 'name': 'Football_RKick'},
#                                  {'music': False, 'name': 'Backward'},
#                                  {'music': True, 'name': '我们是共产主义接班人'},
#                                  {'music': True, 'name': 'SorrySorry'},
#                                  {'music': False, 'name': 'Base_GetupB'},
#                                  {'music': False, 'name': 'reset_without_head'},
#                                  {'music': False, 'name': 'Base_Forward'},
#                                  {'music': False, 'name': 'GetupFront'},
#                                  {'music': False, 'name': 'TurnL_tiny'},
#                                  {'music': False, 'name': 'Rightward'},
#                                  {'music': False, 'name': 'Victory'},
#                                  {'music': False, 'name': 'Base_Leftward'},
#                                  {'music': False, 'name': 'rightmovestep'},
#                                  {'music': False, 'name': 'Football_RShoot'},
#                                  {'music': False, 'name': 'RightHitForward'},
#                                  {'music': False, 'name': 'Leftward'},
#                                  {'music': False, 'name': 'TurnLeft'},
#                                  {'music': True, 'name': 'HappyBirthday'},
#                                  {'music': False, 'name': 'TurnLeft1'},
#                                  {'music': False, 'name': 'Base_Rightward'},
#                                  {'music': False, 'name': 'Fight_LSideHit'},
#                                  {'music': True, 'name': '从这里出发'},
#                                  {'music': False, 'name': 'Fight_RSideHit'},
#                                  {'music': False, 'name': 'OneStepMoveLeft'},
#                                  {'music': False, 'name': 'Forward'},
#                                  {'music': False, 'name': 'Football_LKeep'},
#                                  {'music': False, 'name': 'OneStepMoveRight'},
#                                  {'music': False, 'name': 'Fight_LHit'},
#                                  {'music': False, 'name': 'Base_TurnR'},
#                                  {'music': True, 'name': '唱支山歌给党听'},
#                                  {'music': True, 'name': 'CombinationOfSongs'},
#                                  {'music': False, 'name': 'OneStepTurnLeft'},
#                                  {'music': False, 'name': 'Football_LKick'},
#                                  {'music': False, 'name': 'LeftHitForward'},
#                                  {'music': True, 'name': 'GetUp'},
#                                  {'music': False, 'name': 'PushUp'},
#                                  {'music': False, 'name': 'OneStepBackward'},
#                                  {'music': False, 'name': 'Football_LShoot'},
#                                  {'music': True, 'name': 'GangnamStyle'},
#                                  {'music': False, 'name': 'Base_TurnL'},
#                                  {'music': False, 'name': 'calibration'},
#                                  {'music': False, 'name': 'RightSidePunch'},
#                                  {'music': False, 'name': 'ActionAging'},
#                                  {'music': False, 'name': 'GoalKeeper1'},
#                                  {'music': True, 'name': '光荣啊！中国共青团'},
#                                  {'music': False, 'name': 'Backward1'},
#                                  {'music': False, 'name': 'knee right'},
#                                  {'music': False,
#                                   'name': 'ExitEnergySavingReset'},
#                                  {'music': True, 'name': '海草舞'},
#                                  {'music': False, 'name': 'GetupRear'},
#                                  {'music': False, 'name': 'leftmovestep'},
#                                  {'music': False, 'name': 'Hug'},
#                                  {'music': False, 'name': 'Stop'},
#                                  {'music': False, 'name': 'Forward1'},
#                                  {'music': False, 'name': 'ShootLeft'},
#                                  {'music': False, 'name': 'Base_Backward'},
#                                  {'music': True, 'name': '我们都是追梦人'},
#                                  {'music': False, 'name': 'Left slide tackle'},
#                                  {'music': True, 'name': 'LittleApple'},
#                                  {'music': False, 'name': 'ActionAging1'},
#                                  {'music': False, 'name': 'Reset'},
#                                  {'music': False, 'name': 'knee left'}],
#           'system_layers_motions': [{'music': False, 'name': 'Track_TurnR'},
#                                     {'music': False, 'name': 'F_MoveR'},
#                                     {'music': False, 'name': 'F_MoveL'},
#                                     {'music': False, 'name': 'F_Reset_S'},
#                                     {'music': False, 'name': 'F_MoveF_A'},
#                                     {'music': False, 'name': 'H_Str_R'},
#                                     {'music': False, 'name': 'CarryBox'},
#                                     {'music': False, 'name': 'Hd_Wacth_F'},
#                                     {'music': False, 'name': 'F_MoveB_R'},
#                                     {'music': False, 'name': 'H_Rise_L'},
#                                     {'music': False, 'name': 'H_Wave_R'},
#                                     {'music': False, 'name': 'Hd_Wacth_L'},
#                                     {'music': False, 'name': 'F_TurnR_T'},
#                                     {'music': False, 'name': 'Hd_Wacth_R'},
#                                     {'music': False, 'name': 'F_MoveF_B'},
#                                     {'music': False, 'name': 'F_TurnL_T'},
#                                     {'music': False, 'name': 'H_Reset_S'},
#                                     {'music': False, 'name': 'H_HWave_C'},
#                                     {'music': False, 'name': 'H_Bec_L'},
#                                     {'music': False, 'name': 'H_HWave_L'},
#                                     {'music': False, 'name': 'F_MoveB_B'},
#                                     {'music': False, 'name': 'H_WaveRH'},
#                                     {'music': False, 'name': 'Hd_SwivelH'},
#                                     {'music': False, 'name': 'H_Str_L'},
#                                     {'music': False, 'name': 'H_Bec_R'},
#                                     {'music': False, 'name': 'H_Wave_L'},
#                                     {'music': False, 'name': 'Track_TurnL'},
#                                     {'music': False, 'name': 'H_RBox'},
#                                     {'music': False, 'name': 'H_Bec_B'},
#                                     {'music': False, 'name': 'Reset_S'},
#                                     {'music': False, 'name': 'H_Wave_B'},
#                                     {'music': False, 'name': 'F_MoveF_E'},
#                                     {'music': False, 'name': 'F_MoveB_A'},
#                                     {'music': False, 'name': 'F_MoveF_R'},
#                                     {'music': False, 'name': 'H_Rise_B'},
#                                     {'music': False, 'name': 'H_Rise_R'},
#                                     {'music': False, 'name': 'F_MoveB_E'},
#                                     {'music': False, 'name': 'Hd_Reset_S'},
#                                     {'music': False, 'name': 'H_Str_B'}],
#           'user_hts_motions': [],
#           'user_layers_motions': []},
#  'msg': 'Success'}

# %%
YanAPI.sync_play_motion('H_Wave_R',speed=1)
# Out:
# 2024-06-18  11:48:09 Tue sync_play_motion ERROR play motion failed error code = 103 msg = Cannot found the motion file!
# False
